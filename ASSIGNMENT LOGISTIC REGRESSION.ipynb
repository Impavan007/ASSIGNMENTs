# %%
#Write a Python program that loads a dataset, splits it into training and testing sets, applies Logistic Regression, and prints the model accuracy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
iris = load_iris()

df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['Target']=iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Target, Length: 150, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([0, 0, 2, 0, 0, 2, 0, 2, 2, 0, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1, 2, 1,
#        2, 1, 1, 0, 0, 2, 0, 2])

# %%
acc=accuracy_score(y_test,y_predict)
acc
# Out:
# 0.9666666666666667

# %%
#Write a Python program to apply L1 regularization (Lasso) on a dataset using LogisticRegression(penalty='l1') and print the model accuracy

# %%
model2 = LogisticRegression(penalty='l1', solver='liblinear', C=1.0, random_state=42)
model2.fit(x_train, y_train)
# Out:
# LogisticRegression(penalty='l1', random_state=42, solver='liblinear')

# %%
y_predict2=model2.predict(x_test)
y_predict2
# Out:
# array([0, 0, 2, 0, 0, 1, 0, 2, 2, 0, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1, 1, 1,
#        2, 1, 1, 0, 0, 2, 0, 2])

# %%
acc2=accuracy_score(y_test,y_predict2)
acc2
# Out:
# 0.9666666666666667

# %%
model3 = LogisticRegression(penalty='l2', solver='liblinear', C=1.0, random_state=2)
model3.fit(x_train, y_train)
y_predict3=model2.predict(x_test)
y_predict3
acc3=accuracy_score(y_test,y_predict2)
acc3
# Out:
# 0.9666666666666667

# %%
model4 = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=0.5,max_iter=5000, C=1.0, random_state=2)
model4.fit(x_train, y_train)

# Predict on test data
y_pred4 = model4.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred4)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
from sklearn.multiclass import OneVsRestClassifier
model5 = OneVsRestClassifier(LogisticRegression(solver='liblinear', random_state=42))
model5.fit(x_train, y_train)

# Make predictions
y_pred5 = model.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred5)
accuracy
# Out:
# 0.9666666666666667

# %%
model = LogisticRegression(solver='liblinear', random_state=2)
param_grid = {
    "C": [0.01, 0.1, 1, 10, 100],  # Regularization strength
    "penalty": ["l1", "l2"]  # Regularization type
}
# Apply GridSearchCV
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)

# Get best hyperparameters
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Predict using the best model
y_pred = best_model.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9333333333333333

# %%
best_params
# Out:
# {'C': 1, 'penalty': 'l2'}

# %%
best_model
# Out:
# LogisticRegression(C=1, random_state=2, solver='liblinear')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Define Stratified K-Fold Cross-Validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize list to store accuracy scores
accuracy_scores = []

# Loop through each fold
for train_index, test_index in kf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = y[train_index], y[test_index]

    # Train Logistic Regression model
    model = LogisticRegression(solver='liblinear', random_state=42)
    model.fit(X_train, Y_train)

    # Predict on test set
    y_pred = model.predict(X_test)

    # Compute accuracy and store it
    acc = accuracy_score(Y_test, y_pred)
    accuracy_scores.append(acc)

# Calculate and print average accuracy
avg_accuracy = np.mean(accuracy_scores)
print("Average Accuracy using Stratified K-Fold Cross-Validation:", avg_accuracy)
# Out:
# Average Accuracy using Stratified K-Fold Cross-Validation: 0.96

# %%
# Assuming the last column is the target (change column names if needed)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 0         0
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
param_grid = {
    'C': np.logspace(-4, 4, 20),  # Regularization strength
    'penalty': ['l1', 'l2'],  # Type of regularization
    'solver': ['liblinear', 'saga']  # Solvers that support L1 and L2
}
model = LogisticRegression(random_state=2, max_iter=5000)

random_search = RandomizedSearchCV(model, param_grid, n_iter=10, cv=5, scoring='accuracy', n_jobs=-1, random_state=2)

# %%
random_search.fit(x_train, y_train)

# Get best model and parameters
best_model = random_search.best_estimator_
best_params = random_search.best_params_

# Predict on test data
y_pred = best_model.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 1.0
